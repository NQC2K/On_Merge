# %%
from databricks.sdk import WorkspaceClient

execute_task = False
w = WorkspaceClient()

# %%
commit_id = "611b7a267efd7a2e426fe452d07b31f210fdbfc7"
commit_msg = "add pics"
commit_datetime = "2026-04-08T22:56:16+07:00"

# %%
if execute_task:
    job_name = "client_success_data_processing_dev"

    # Find the job by name
    job = next(
        (j for j in w.jobs.list() if j.settings.name == job_name),
        None
    )

    if job is None:
        raise ValueError(f"Job not found: {job_name}")

    print("Job ID:", job.job_id)

    # Trigger the job
    run = w.jobs.run_now(job_id=job.job_id)

    print("Run ID:", run.run_id)
else:
    # Do nothing
    pass
